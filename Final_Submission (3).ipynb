# %%
# !pip install tensorflow==2.2.0

# %%
from zipfile import ZipFile
with ZipFile('/content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/pneumonia_dataset.zip') as file:
  file.extractall('/content/Data/')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from glob import glob
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator

DATASET_PATH = '/content/Data/'

normal_images = pd.DataFrame({'Image_Path':glob(DATASET_PATH + "pneumonia_dataset/train/normal/*.png"), 'label':'No'})
pneumonia_images = pd.DataFrame({'Image_Path':glob(DATASET_PATH + "pneumonia_dataset/train/pneumonia/*.png"), 'label':'Yes'})

train_df = pd.concat([normal_images,pneumonia_images], axis=0, sort =False)
test_df = pd.read_csv(DATASET_PATH + "pneumonia_dataset/test.csv")
test_df['Image_Path'] = "/content/Data/pneumonia_dataset/test/" + test['filename']

print(train_df.shape) # (2425,2)
print(test_df.shape) # (606,1)

train_df , validation_df = train_test_split(train_df,random_state=101 ,test_size=0.20)

train_df.to_csv(DATASET_PATH + 'train_df.csv', index=False)
test_df.to_csv(DATASET_PATH + 'test_df.csv', index=False)
validation_df.to_csv(DATASET_PATH + 'validation_df.csv', index=False)
# Out:
# (2425, 2)
# (606, 2)

# %%
BATCH_SIZE = 32
EPOCHS = 20
IMAGE_SHAPE = (224,224,3)
TARGET_SIZE = (224,224)

train_data = pd.read_csv(DATASET_PATH + 'train_df.csv')
validation_data = pd.read_csv(DATASET_PATH + 'validation_df.csv')

# Training Generator
train_datagen = ImageDataGenerator(rescale=1./255 , rotation_range=20 , width_shift_range=0.10, height_shift_range=0.10,
                                   horizontal_flip=True, vertical_flip=True,zoom_range=0.10, shear_range=0.10, fill_mode='nearest')

train_generator = train_datagen.flow_from_dataframe(dataframe=train_data,x_col='Image_Path', y_col='label',target_size=TARGET_SIZE,
                                                    class_mode='categorical',shuffle=True,batch_size=BATCH_SIZE)

# Validation datagen
validation_datagen = ImageDataGenerator(rescale=1./255)
validation_generator = train_datagen.flow_from_dataframe(dataframe=validation_data, x_col='Image_Path', y_col='label',target_size=TARGET_SIZE,
                                                    class_mode='categorical',shuffle=False,batch_size=BATCH_SIZE)


STEPS_PER_EPOCHS = len(train_data) // BATCH_SIZE
VAL_STEPS_PER_EPOCHS = len(validation_data) // BATCH_SIZE

# Show Images with Train DataGenerator
sample_image = train_data.sample(1).reset_index(drop=True)
sample_generator = train_datagen.flow_from_dataframe(sample_image,x_col='Image_Path', y_col='label',target_size=TARGET_SIZE,
                                                    class_mode='categorical',shuffle=False,batch_size=BATCH_SIZE)

plt.figure(figsize=(18,12))
for i in np.arange(16):
    plt.subplot(4,4,i+1)
    for image, label in sample_generator:
        plt.imshow(image[0])
        plt.axis('off')
        break

# %%
from sklearn.metrics import precision_score , recall_score , f1_score , log_loss, accuracy_score
from tensorflow.keras.callbacks import Callback

class Validation(Callback):
    def __init__(self, data_generator,df):
        self.validation_generator = data_generator
        self.dataframe = df

    def on_epoch_end(self, epoch, logs=None):
        prediction = self.model.predict_generator(self.validation_generator)
        prediction_prob = prediction[:,1]
        prediction = np.argmax(prediction, axis=1)
        actual = self.dataframe['label'].tolist()
        actual = [1 if x =='Yes' else 0 for x in actual]
        recall = recall_score(actual, prediction, pos_label=0)
        precision = precision_score(actual, prediction, pos_label=0)
        accuracy = accuracy_score(actual, prediction)
        # F1_score = f1_score(actual, prediction)
        loss = log_loss(actual, prediction_prob)

        logs['val_recall'] ,logs['val_precision'],logs['val_accuracy'],logs['val_loss'] = recall , precision, accuracy, loss

val_df =pd.read_csv(DATASET_PATH + "validation_df.csv")
validation = Validation(validation_generator, val_df)

# %%
from tensorflow.keras.applications.mobilenet import MobileNet
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.layers import Dense, MaxPooling2D , GlobalAveragePooling2D , Dropout
from tensorflow.keras.callbacks import ModelCheckpoint , EarlyStopping , ReduceLROnPlateau , Callback
from tensorflow.keras.optimizers import Adam , SGD

pre_trained_model = MobileNet(input_shape=IMAGE_SHAPE , include_top=False, weights='imagenet')

for layer in pre_trained_model.layers:
    layer.trainable = True

last_output_layer = pre_trained_model.layers[-1].output
x = GlobalAveragePooling2D()(last_output_layer)
x = Dense(512, activation='relu')(x)
x = Dropout(0.20)(x)
x = Dense(256,activation='relu')(x)
x = Dropout(0.20)(x)
x = Dense(128,activation='relu')(x)
x = Dropout(0.20)(x)
x = Dense(2,activation='softmax')(x)

model = Model(inputs = pre_trained_model.input , outputs = x)
model.summary()

model.compile(optimizer=Adam(learning_rate=0.005), loss='categorical_crossentropy', metrics=['accuracy'])

model_checkpoint = ModelCheckpoint(filepath="/content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/{val_accuracy:.2f}{epoch:2d}.h5",
                                   monitor='val_accuracy',
                                   save_weights_only=False,
                                   save_best_only=False,
                                   mode='max',
                                   verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss',
                              factor=0.1,
                              patience=10,
                              verbose=1,
                              mode ='min')

model.fit_generator(generator=train_generator, steps_per_epoch=STEPS_PER_EPOCHS ,callbacks=[validation,model_checkpoint,reduce_lr],
                     epochs=60, verbose=1)
model.save(DATASET_PATH + "model.h5")
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 225, 225, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 112, 112, 32)      864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 112, 112, 32)      128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 112, 112, 32)      288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 112, 112, 32)      128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 112, 112, 32)      0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 112, 112, 64)      2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 112, 112, 64)      256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 112, 112, 64)      0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 113, 113, 64)      0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 56, 56, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 56, 56, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 56, 56, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 56, 56, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 56, 56, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 56, 56, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 56, 56, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 56, 56, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 57, 57, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 28, 28, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 28, 28, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 28, 28, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 28, 28, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 28, 28, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 28, 28, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 28, 28, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 28, 28, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 29, 29, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 14, 14, 256)       2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 14, 14, 256)       1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 14, 14, 256)       0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 14, 14, 512)       131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 14, 14, 512)       4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 14, 14, 512)       262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 14, 14, 512)       2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 14, 14, 512)       0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 15, 15, 512)       0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 7, 7, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 7, 7, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 7, 7, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 7, 7, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 7, 7, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 7, 7, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 7, 7, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 7, 7, 1024)        0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 1024)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 512)               524800
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 512)               0
# _________________________________________________________________
# dense_17 (Dense)             (None, 256)               131328
# _________________________________________________________________
# dropout_17 (Dropout)         (None, 256)               0
# _________________________________________________________________
# dense_18 (Dense)             (None, 128)               32896
# _________________________________________________________________
# dropout_18 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_19 (Dense)             (None, 2)                 258
# =================================================================
# Total params: 3,918,146
# Trainable params: 3,896,258
# Non-trainable params: 21,888
# _________________________________________________________________
# Epoch 1/60
# 60/60 [==============================] - ETA: 0s - loss: 0.8799 - accuracy: 0.5765
# Epoch 00001: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.53 1.h5
# 60/60 [==============================] - 71s 1s/step - loss: 0.8799 - accuracy: 0.5765 - val_recall: 1.0000 - val_precision: 0.5278 - val_accuracy: 0.5278 - val_loss: 3.5966 - lr: 0.0050
# Epoch 2/60
# 60/60 [==============================] - ETA: 0s - loss: 0.6548 - accuracy: 0.6478
# Epoch 00002: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.53 2.h5
# 60/60 [==============================] - 70s 1s/step - loss: 0.6548 - accuracy: 0.6478 - val_recall: 1.0000 - val_precision: 0.5278 - val_accuracy: 0.5278 - val_loss: 2.3252 - lr: 0.0050
# Epoch 3/60
# 60/60 [==============================] - ETA: 0s - loss: 0.6424 - accuracy: 0.6640
# Epoch 00003: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.54 3.h5
# 60/60 [==============================] - 70s 1s/step - loss: 0.6424 - accuracy: 0.6640 - val_recall: 0.9883 - val_precision: 0.5338 - val_accuracy: 0.5381 - val_loss: 0.8155 - lr: 0.0050
# Epoch 4/60
# 60/60 [==============================] - ETA: 0s - loss: 0.6387 - accuracy: 0.6656
# Epoch 00004: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.60 4.h5
# 60/60 [==============================] - 73s 1s/step - loss: 0.6387 - accuracy: 0.6656 - val_recall: 0.9766 - val_precision: 0.5695 - val_accuracy: 0.5979 - val_loss: 0.7541 - lr: 0.0050
# Epoch 5/60
# 60/60 [==============================] - ETA: 0s - loss: 0.6299 - accuracy: 0.6740
# Epoch 00005: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.52 5.h5
# 60/60 [==============================] - 73s 1s/step - loss: 0.6299 - accuracy: 0.6740 - val_recall: 0.9922 - val_precision: 0.5259 - val_accuracy: 0.5237 - val_loss: 1.2252 - lr: 0.0050
# Epoch 6/60
# 60/60 [==============================] - ETA: 0s - loss: 0.6358 - accuracy: 0.6415
# Epoch 00006: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.65 6.h5
# 60/60 [==============================] - 73s 1s/step - loss: 0.6358 - accuracy: 0.6415 - val_recall: 0.6797 - val_precision: 0.6591 - val_accuracy: 0.6454 - val_loss: 0.6105 - lr: 0.0050
# Epoch 7/60
# 60/60 [==============================] - ETA: 0s - loss: 0.6232 - accuracy: 0.6703
# Epoch 00007: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.57 7.h5
# 60/60 [==============================] - 72s 1s/step - loss: 0.6232 - accuracy: 0.6703 - val_recall: 0.9766 - val_precision: 0.5519 - val_accuracy: 0.5691 - val_loss: 0.9217 - lr: 0.0050
# Epoch 8/60
# 60/60 [==============================] - ETA: 0s - loss: 0.6170 - accuracy: 0.6861
# Epoch 00008: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.52 8.h5
# 60/60 [==============================] - 72s 1s/step - loss: 0.6170 - accuracy: 0.6861 - val_recall: 0.1055 - val_precision: 0.9000 - val_accuracy: 0.5216 - val_loss: 0.8757 - lr: 0.0050
# Epoch 9/60
# 60/60 [==============================] - ETA: 0s - loss: 0.6146 - accuracy: 0.6693
# Epoch 00009: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.69 9.h5
# 60/60 [==============================] - 73s 1s/step - loss: 0.6146 - accuracy: 0.6693 - val_recall: 0.8398 - val_precision: 0.6636 - val_accuracy: 0.6907 - val_loss: 0.6060 - lr: 0.0050
# Epoch 10/60
# 60/60 [==============================] - ETA: 0s - loss: 0.6085 - accuracy: 0.6850
# Epoch 00010: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.6910.h5
# 60/60 [==============================] - 73s 1s/step - loss: 0.6085 - accuracy: 0.6850 - val_recall: 0.6719 - val_precision: 0.7288 - val_accuracy: 0.6948 - val_loss: 0.6108 - lr: 0.0050
# Epoch 11/60
# 60/60 [==============================] - ETA: 0s - loss: 0.6178 - accuracy: 0.6913
# Epoch 00011: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.6411.h5
# 60/60 [==============================] - 70s 1s/step - loss: 0.6178 - accuracy: 0.6913 - val_recall: 0.8906 - val_precision: 0.6113 - val_accuracy: 0.6433 - val_loss: 0.6308 - lr: 0.0050
# Epoch 12/60
# 60/60 [==============================] - ETA: 0s - loss: 0.6060 - accuracy: 0.6950
# Epoch 00012: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.6012.h5
# 60/60 [==============================] - 70s 1s/step - loss: 0.6060 - accuracy: 0.6950 - val_recall: 0.4180 - val_precision: 0.7133 - val_accuracy: 0.6041 - val_loss: 0.6441 - lr: 0.0050
# Epoch 13/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5954 - accuracy: 0.7018
# Epoch 00013: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.6513.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.5954 - accuracy: 0.7018 - val_recall: 0.7891 - val_precision: 0.6332 - val_accuracy: 0.6474 - val_loss: 0.6288 - lr: 0.0050
# Epoch 14/60
# 60/60 [==============================] - ETA: 0s - loss: 0.6008 - accuracy: 0.6997
# Epoch 00014: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7014.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.6008 - accuracy: 0.6997 - val_recall: 0.6445 - val_precision: 0.7569 - val_accuracy: 0.7031 - val_loss: 0.5771 - lr: 0.0050
# Epoch 15/60
# 60/60 [==============================] - ETA: 0s - loss: 0.6069 - accuracy: 0.6960
# Epoch 00015: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.6215.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.6069 - accuracy: 0.6960 - val_recall: 0.9180 - val_precision: 0.5934 - val_accuracy: 0.6247 - val_loss: 0.6246 - lr: 0.0050
# Epoch 16/60
# 60/60 [==============================] - ETA: 0s - loss: 0.6018 - accuracy: 0.6992
# Epoch 00016: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.6816.h5
# 60/60 [==============================] - 68s 1s/step - loss: 0.6018 - accuracy: 0.6992 - val_recall: 0.6211 - val_precision: 0.7361 - val_accuracy: 0.6825 - val_loss: 0.5796 - lr: 0.0050
# Epoch 17/60
# 60/60 [==============================] - ETA: 0s - loss: 0.6039 - accuracy: 0.7028
# Epoch 00017: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7017.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.6039 - accuracy: 0.7028 - val_recall: 0.8672 - val_precision: 0.6687 - val_accuracy: 0.7031 - val_loss: 0.5852 - lr: 0.0050
# Epoch 18/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5940 - accuracy: 0.7123
# Epoch 00018: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7118.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.5940 - accuracy: 0.7123 - val_recall: 0.6680 - val_precision: 0.7600 - val_accuracy: 0.7134 - val_loss: 0.5617 - lr: 0.0050
# Epoch 19/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5827 - accuracy: 0.7180
# Epoch 00019: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.5619.h5
# 60/60 [==============================] - 70s 1s/step - loss: 0.5827 - accuracy: 0.7180 - val_recall: 0.9531 - val_precision: 0.5471 - val_accuracy: 0.5588 - val_loss: 0.8530 - lr: 0.0050
# Epoch 20/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5914 - accuracy: 0.7180
# Epoch 00020: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.6220.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.5914 - accuracy: 0.7180 - val_recall: 0.3398 - val_precision: 0.8529 - val_accuracy: 0.6206 - val_loss: 0.6628 - lr: 0.0050
# Epoch 21/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5946 - accuracy: 0.6944
# Epoch 00021: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.6521.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.5946 - accuracy: 0.6944 - val_recall: 0.9219 - val_precision: 0.6130 - val_accuracy: 0.6515 - val_loss: 0.6276 - lr: 0.0050
# Epoch 22/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5853 - accuracy: 0.7055
# Epoch 00022: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7222.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.5853 - accuracy: 0.7055 - val_recall: 0.7656 - val_precision: 0.7232 - val_accuracy: 0.7216 - val_loss: 0.5785 - lr: 0.0050
# Epoch 23/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5886 - accuracy: 0.7144
# Epoch 00023: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7123.h5
# 60/60 [==============================] - 68s 1s/step - loss: 0.5886 - accuracy: 0.7144 - val_recall: 0.8125 - val_precision: 0.6933 - val_accuracy: 0.7113 - val_loss: 0.6090 - lr: 0.0050
# Epoch 24/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5959 - accuracy: 0.7102
# Epoch 00024: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.6324.h5
# 60/60 [==============================] - 68s 1s/step - loss: 0.5959 - accuracy: 0.7102 - val_recall: 0.9219 - val_precision: 0.5945 - val_accuracy: 0.6268 - val_loss: 0.6614 - lr: 0.0050
# Epoch 25/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5791 - accuracy: 0.7206
# Epoch 00025: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.6725.h5
# 60/60 [==============================] - 68s 1s/step - loss: 0.5791 - accuracy: 0.7206 - val_recall: 0.9258 - val_precision: 0.6253 - val_accuracy: 0.6680 - val_loss: 0.7619 - lr: 0.0050
# Epoch 26/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5890 - accuracy: 0.6971
# Epoch 00026: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.6726.h5
# 60/60 [==============================] - 67s 1s/step - loss: 0.5890 - accuracy: 0.6971 - val_recall: 0.8398 - val_precision: 0.6418 - val_accuracy: 0.6680 - val_loss: 0.6176 - lr: 0.0050
# Epoch 27/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5854 - accuracy: 0.7165
# Epoch 00027: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7227.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.5854 - accuracy: 0.7165 - val_recall: 0.7070 - val_precision: 0.7510 - val_accuracy: 0.7216 - val_loss: 0.5784 - lr: 0.0050
# Epoch 28/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5923 - accuracy: 0.7096
# Epoch 00028: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.5428.h5
#
# Epoch 00028: ReduceLROnPlateau reducing learning rate to 0.0004999999888241291.
# 60/60 [==============================] - 69s 1s/step - loss: 0.5923 - accuracy: 0.7096 - val_recall: 0.1523 - val_precision: 0.8864 - val_accuracy: 0.5423 - val_loss: 0.6898 - lr: 0.0050
# Epoch 29/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5715 - accuracy: 0.7238
# Epoch 00029: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.6529.h5
# 60/60 [==============================] - 68s 1s/step - loss: 0.5715 - accuracy: 0.7238 - val_recall: 0.4219 - val_precision: 0.8438 - val_accuracy: 0.6536 - val_loss: 0.6099 - lr: 5.0000e-04
# Epoch 30/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5550 - accuracy: 0.7238
# Epoch 00030: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.6930.h5
# 60/60 [==============================] - 68s 1s/step - loss: 0.5550 - accuracy: 0.7238 - val_recall: 0.5352 - val_precision: 0.8253 - val_accuracy: 0.6948 - val_loss: 0.5699 - lr: 5.0000e-04
# Epoch 31/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5474 - accuracy: 0.7369
# Epoch 00031: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7231.h5
# 60/60 [==============================] - 67s 1s/step - loss: 0.5474 - accuracy: 0.7369 - val_recall: 0.6992 - val_precision: 0.7458 - val_accuracy: 0.7155 - val_loss: 0.5559 - lr: 5.0000e-04
# Epoch 32/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5524 - accuracy: 0.7406
# Epoch 00032: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7432.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.5524 - accuracy: 0.7406 - val_recall: 0.7383 - val_precision: 0.7590 - val_accuracy: 0.7381 - val_loss: 0.5324 - lr: 5.0000e-04
# Epoch 33/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5495 - accuracy: 0.7353
# Epoch 00033: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7233.h5
# 60/60 [==============================] - 68s 1s/step - loss: 0.5495 - accuracy: 0.7353 - val_recall: 0.7227 - val_precision: 0.7400 - val_accuracy: 0.7196 - val_loss: 0.5462 - lr: 5.0000e-04
# Epoch 34/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5457 - accuracy: 0.7421
# Epoch 00034: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7134.h5
# 60/60 [==============================] - 68s 1s/step - loss: 0.5457 - accuracy: 0.7421 - val_recall: 0.6562 - val_precision: 0.7636 - val_accuracy: 0.7113 - val_loss: 0.5608 - lr: 5.0000e-04
# Epoch 35/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5523 - accuracy: 0.7322
# Epoch 00035: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7135.h5
# 60/60 [==============================] - 68s 1s/step - loss: 0.5523 - accuracy: 0.7322 - val_recall: 0.7188 - val_precision: 0.7302 - val_accuracy: 0.7113 - val_loss: 0.5481 - lr: 5.0000e-04
# Epoch 36/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5433 - accuracy: 0.7400
# Epoch 00036: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7436.h5
# 60/60 [==============================] - 67s 1s/step - loss: 0.5433 - accuracy: 0.7400 - val_recall: 0.7891 - val_precision: 0.7372 - val_accuracy: 0.7402 - val_loss: 0.5406 - lr: 5.0000e-04
# Epoch 37/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5369 - accuracy: 0.7364
# Epoch 00037: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7137.h5
# 60/60 [==============================] - 67s 1s/step - loss: 0.5369 - accuracy: 0.7364 - val_recall: 0.7930 - val_precision: 0.7000 - val_accuracy: 0.7113 - val_loss: 0.5568 - lr: 5.0000e-04
# Epoch 38/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5396 - accuracy: 0.7490
# Epoch 00038: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7238.h5
# 60/60 [==============================] - 66s 1s/step - loss: 0.5396 - accuracy: 0.7490 - val_recall: 0.7969 - val_precision: 0.7133 - val_accuracy: 0.7237 - val_loss: 0.5434 - lr: 5.0000e-04
# Epoch 39/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5407 - accuracy: 0.7395
# Epoch 00039: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7439.h5
# 60/60 [==============================] - 67s 1s/step - loss: 0.5407 - accuracy: 0.7395 - val_recall: 0.7617 - val_precision: 0.7443 - val_accuracy: 0.7361 - val_loss: 0.5364 - lr: 5.0000e-04
# Epoch 40/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5385 - accuracy: 0.7490
# Epoch 00040: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7440.h5
# 60/60 [==============================] - 68s 1s/step - loss: 0.5385 - accuracy: 0.7490 - val_recall: 0.7344 - val_precision: 0.7673 - val_accuracy: 0.7423 - val_loss: 0.5234 - lr: 5.0000e-04
# Epoch 41/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5337 - accuracy: 0.7510
# Epoch 00041: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7441.h5
# 60/60 [==============================] - 68s 1s/step - loss: 0.5337 - accuracy: 0.7510 - val_recall: 0.7891 - val_precision: 0.7399 - val_accuracy: 0.7423 - val_loss: 0.5399 - lr: 5.0000e-04
# Epoch 42/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5316 - accuracy: 0.7490
# Epoch 00042: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7342.h5
# 60/60 [==============================] - 68s 1s/step - loss: 0.5316 - accuracy: 0.7490 - val_recall: 0.7617 - val_precision: 0.7386 - val_accuracy: 0.7320 - val_loss: 0.5462 - lr: 5.0000e-04
# Epoch 43/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5392 - accuracy: 0.7427
# Epoch 00043: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7243.h5
# 60/60 [==============================] - 68s 1s/step - loss: 0.5392 - accuracy: 0.7427 - val_recall: 0.7617 - val_precision: 0.7276 - val_accuracy: 0.7237 - val_loss: 0.5433 - lr: 5.0000e-04
# Epoch 44/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5325 - accuracy: 0.7484
# Epoch 00044: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7444.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.5325 - accuracy: 0.7484 - val_recall: 0.7344 - val_precision: 0.7611 - val_accuracy: 0.7381 - val_loss: 0.5431 - lr: 5.0000e-04
# Epoch 45/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5247 - accuracy: 0.7563
# Epoch 00045: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7045.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.5247 - accuracy: 0.7563 - val_recall: 0.7695 - val_precision: 0.6961 - val_accuracy: 0.7010 - val_loss: 0.5599 - lr: 5.0000e-04
# Epoch 46/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5239 - accuracy: 0.7573
# Epoch 00046: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7446.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.5239 - accuracy: 0.7573 - val_recall: 0.8008 - val_precision: 0.7295 - val_accuracy: 0.7381 - val_loss: 0.5479 - lr: 5.0000e-04
# Epoch 47/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5362 - accuracy: 0.7437
# Epoch 00047: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7147.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.5362 - accuracy: 0.7437 - val_recall: 0.7305 - val_precision: 0.7248 - val_accuracy: 0.7113 - val_loss: 0.5535 - lr: 5.0000e-04
# Epoch 48/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5271 - accuracy: 0.7552
# Epoch 00048: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7348.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.5271 - accuracy: 0.7552 - val_recall: 0.8242 - val_precision: 0.7128 - val_accuracy: 0.7320 - val_loss: 0.5735 - lr: 5.0000e-04
# Epoch 49/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5265 - accuracy: 0.7552
# Epoch 00049: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7149.h5
# 60/60 [==============================] - 70s 1s/step - loss: 0.5265 - accuracy: 0.7552 - val_recall: 0.8164 - val_precision: 0.6921 - val_accuracy: 0.7113 - val_loss: 0.5659 - lr: 5.0000e-04
# Epoch 50/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5156 - accuracy: 0.7552
# Epoch 00050: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7450.h5
#
# Epoch 00050: ReduceLROnPlateau reducing learning rate to 4.9999996554106475e-05.
# 60/60 [==============================] - 69s 1s/step - loss: 0.5156 - accuracy: 0.7552 - val_recall: 0.7812 - val_precision: 0.7463 - val_accuracy: 0.7443 - val_loss: 0.5376 - lr: 5.0000e-04
# Epoch 51/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5169 - accuracy: 0.7631
# Epoch 00051: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7351.h5
# 60/60 [==============================] - 70s 1s/step - loss: 0.5169 - accuracy: 0.7631 - val_recall: 0.7695 - val_precision: 0.7378 - val_accuracy: 0.7340 - val_loss: 0.5378 - lr: 5.0000e-05
# Epoch 52/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5110 - accuracy: 0.7563
# Epoch 00052: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7152.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.5110 - accuracy: 0.7563 - val_recall: 0.7617 - val_precision: 0.7040 - val_accuracy: 0.7052 - val_loss: 0.5607 - lr: 5.0000e-05
# Epoch 53/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5156 - accuracy: 0.7600
# Epoch 00053: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7253.h5
# 60/60 [==============================] - 70s 1s/step - loss: 0.5156 - accuracy: 0.7600 - val_recall: 0.7656 - val_precision: 0.7232 - val_accuracy: 0.7216 - val_loss: 0.5421 - lr: 5.0000e-05
# Epoch 54/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5162 - accuracy: 0.7558
# Epoch 00054: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7454.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.5162 - accuracy: 0.7558 - val_recall: 0.7969 - val_precision: 0.7312 - val_accuracy: 0.7381 - val_loss: 0.5391 - lr: 5.0000e-05
# Epoch 55/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5233 - accuracy: 0.7500
# Epoch 00055: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7455.h5
# 60/60 [==============================] - 70s 1s/step - loss: 0.5233 - accuracy: 0.7500 - val_recall: 0.7773 - val_precision: 0.7453 - val_accuracy: 0.7423 - val_loss: 0.5296 - lr: 5.0000e-05
# Epoch 56/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5257 - accuracy: 0.7490
# Epoch 00056: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7356.h5
# 60/60 [==============================] - 70s 1s/step - loss: 0.5257 - accuracy: 0.7490 - val_recall: 0.8125 - val_precision: 0.7099 - val_accuracy: 0.7258 - val_loss: 0.5436 - lr: 5.0000e-05
# Epoch 57/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5077 - accuracy: 0.7689
# Epoch 00057: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7457.h5
# 60/60 [==============================] - 69s 1s/step - loss: 0.5077 - accuracy: 0.7689 - val_recall: 0.8125 - val_precision: 0.7324 - val_accuracy: 0.7443 - val_loss: 0.5385 - lr: 5.0000e-05
# Epoch 58/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5086 - accuracy: 0.7621
# Epoch 00058: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7458.h5
# 60/60 [==============================] - 70s 1s/step - loss: 0.5086 - accuracy: 0.7621 - val_recall: 0.7852 - val_precision: 0.7390 - val_accuracy: 0.7402 - val_loss: 0.5411 - lr: 5.0000e-05
# Epoch 59/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5160 - accuracy: 0.7526
# Epoch 00059: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7459.h5
# 60/60 [==============================] - 70s 1s/step - loss: 0.5160 - accuracy: 0.7526 - val_recall: 0.7891 - val_precision: 0.7345 - val_accuracy: 0.7381 - val_loss: 0.5561 - lr: 5.0000e-05
# Epoch 60/60
# 60/60 [==============================] - ETA: 0s - loss: 0.5135 - accuracy: 0.7668
# Epoch 00060: saving model to /content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7160.h5
#
# Epoch 00060: ReduceLROnPlateau reducing learning rate to 4.999999509891496e-06.
# 60/60 [==============================] - 69s 1s/step - loss: 0.5135 - accuracy: 0.7668 - val_recall: 0.7812 - val_precision: 0.7018 - val_accuracy: 0.7093 - val_loss: 0.5641 - lr: 5.0000e-05

# %%
from tensorflow.keras.models import load_model

test_df = pd.read_csv(DATASET_PATH + "test_df.csv")
model = load_model('/content/drive/MyDrive/Computer_Vision_Project/Pneumonia_Image_Classification/DATA/0.7450.h5') #77.61

sample_submission = pd.read_csv('/content/Data/pneumonia_dataset/sample_submission.csv')

# Test Generator
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_dataframe(dataframe=test_df, x_col='Image_Path',y_col=None, target_size=TARGET_SIZE,shuffle=False, batch_size=BATCH_SIZE,
                                                class_mode=None)

prediction = model.predict_generator(test_generator)
sample_submission['label'] = np.argmax(prediction, axis=1)
labels = train_generator.class_indices # No-0 and Yes-1
sample_submission['label'] = sample_submission['label'].replace({1:'pneumonia',0:'normal'})
sample_submission.to_csv(DATASET_PATH + 'sample_submission_6.csv', index=False)
print("Sample_Submission File Saved..")
# Out:
# Found 606 validated image filenames.
# Sample_Submission File Saved..
